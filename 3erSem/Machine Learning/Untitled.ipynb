# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split

# %%
df_titanic = pd.read_csv("https://raw.githubusercontent.com/IvTole/MachineLearning_InferenciaBayesiana_CUGDL/refs/heads/main/data/titanic/titanic_clean.csv")
df_titanic.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    0
# 1       1         1                   Allison, Master. Hudson Trevor    1
# 2       1         0                     Allison, Miss. Helen Loraine    0
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
#
#      age  sibsp  parch  ticket      fare  embarked_Q  embarked_S  familysize  \
# 0  29.00      0      0   24160  211.3375           0           1           1
# 1   0.92      1      2  113781  151.5500           0           1           4
# 2   2.00      1      2  113781  151.5500           0           1           4
# 3  30.00      1      2  113781  151.5500           0           1           4
# 4  25.00      1      2  113781  151.5500           0           1           4
#
# ...

# %%
df_titanic.shape
# Out:
# (1308, 19)

# %%
X = df_titanic.drop(columns= ["survived","fare", "familysize","name","ticket"])
Y = df_titanic["survived"]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   pclass          1308 non-null   int64
#  1   sex             1308 non-null   int64
#  2   age             1308 non-null   float64
#  3   sibsp           1308 non-null   int64
#  4   parch           1308 non-null   int64
#  5   embarked_Q      1308 non-null   int64
#  6   embarked_S      1308 non-null   int64
#  7   isalone         1308 non-null   int64
#  8   title_Miss      1308 non-null   int64
#  9   title_Mr        1308 non-null   int64
#  10  title_Mrs       1308 non-null   int64
#  11  title_Rare      1308 non-null   int64
#  12  fare_log        1308 non-null   float64
#  13  familysize_log  1308 non-null   float64
# dtypes: float64(3), int64(11)
# memory usage: 143.2 KB
