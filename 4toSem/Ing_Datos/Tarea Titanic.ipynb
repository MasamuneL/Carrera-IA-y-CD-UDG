# %% [markdown]
# ## Tarea. Titanic
# ### Ingenieria de Datos
# #### Alan Josue Solano Perez - 16 Abril 2026

# %% [markdown]
# ### Instrucciones:
# Analiza los datos del dataframe titanic.csv responde las siguientes preguntas:
#
#     • Identifica los nombres de las personas que iban en primera clase ordenadas alfabéticamente.
#     • Cuál es el porcentaje de personas que murieron?
#     • Cuál es porcentaje de personas que sobrevivieron y ordenarlas por clase?
#     • Estima el promedio de edad de las personas a bordo del barco?
#     • Cuál es la edad media de las mujeres que viajaban en cada clase?
#     • Indica cuál el porcentaje de menores y mayores de edad que sobrevivieron en cada clase.
#
# Distingue los datos, la información, el conocimiento y la sabiduría de los siguientes datos a desarrolar:
#
#     • Gráfica del porcentaje de menores y mayores de edad que sobrevivieron por clase
#     • Gráfica de la edad media de las mujeres y niños que viajaban en cada clase
#     • Gráfica del porcentaje de personas que sobrevivieron
#     • Gráfica del porcentaje de personas que murieron

# %%
# Importacion de librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/titanic.csv", index_col = "PassengerId")
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Filtramos por nombre alfabeticamente
df.sort_values(by="Name")
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Limpiamos la db
df_clean = df.dropna()
display(df_clean.head())
# Revisamos si quedaron valores vacios
df_clean.isna().sum()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S
# 7                0      0     17463  51.8625   E46        S
# ...

# %%
# Porcentaje de de supervivientes
survived_per = df_clean["Survived"].mean()
survived_per = survived_per*100
print(f'El porcentaje de supervivientes fue de {survived_per:.2f}%')
# Out:
# El porcentaje de supervivientes fue de 67.21%
