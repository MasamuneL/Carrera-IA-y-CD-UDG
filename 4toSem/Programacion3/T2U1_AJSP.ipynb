# %% [markdown]
# ## Tarea 2 Unidad 1 - Programacion 3
# ### 2. Condiciones de Carrera y Locks
# Alan Josue Solano Perez

# %%
#Importamos Librerias
import threading
import time
import random

# %%
#Creamos la clase Inventario

class inventario:
    
    def __init__(self, stock):
        self.local_stock = stock
        self.lock = threading.Lock()

    def stock_add(self, a):
        """
        Agrega 'a' cantidad de cosas al stock
        """
        with self.lock:
            time.sleep(0.0001)
            self.local_stock = self.local_stock + 1
            
    def stock_sub(self, b):
        """
        Substrae 'b' cantidad de cosas al stock
        """
        with self.lock:
            time.sleep(0.0001)
            self.local_stock = self.local_stock - 1

# %%
# Creamos el Inventario
chocolates = inventario(50)

# Creamos varios hilos
hilos = []
for _ in range(5):
    t = threading.Thread(target=chocolates.stock_add(), args = (5,))
    t.start()
    hilos.append(t)

# Esperamos a que terminen
for t in hilos:
    t.join()

print(f'El stock de chocolates actual es de : {chocolates.local_stock()} chocolates')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 7
#       5 hilos = []
#       6 for _ in range(5):
# ----> 7     t = threading.Thread(target=chocolates.stock_add(), args = (5,))
#       8     t.start()
#       9     hilos.append(t)
#
# TypeError: inventario.stock_add() missing 1 required positional argument: 'a'
