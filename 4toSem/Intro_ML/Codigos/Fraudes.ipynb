# %%
# Importamos Librerias
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,precision_recall_curve, auc
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from imblearn.pipeline import Pipeline as ImbPipeline

#librerias de visualizacion
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargamos Los Datos
df = pd.read_csv('../data/trains/fraude.csv')
df = df.drop("Unnamed: 0", axis=1)
df.head()
# Out:
#         monto  antiguedad_cuenta tipo_tarjeta  es_fraude
# 0   46.926809                 39   MasterCard          0
# 1  301.012143                  6         Visa          0
# 2  131.674569                 31         Visa          0
# 3   91.294255                 47         Amex          0
# 4   16.962487                 18   MasterCard          0

# %% [markdown]
# 1. Separamos el taget del dataset

# %%
X = df.drop('es_fraude', axis=1)
y = df['es_fraude']

# %% [markdown]
# 2. Dividimos el Train/test

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# 3. Aplicamos transformaciones a columnas de datos con ColunTransformer

# %%
num_features = ['monto', 'antiguendad_cuenta']
cat_features = ['tipo_tarjeta']

preprocessor = ColumnTransformer(
        transformers=[
            ('num', StandardScaler(), num_features),
            ('cat', OneHotEncoder(), cat_features)
        ])

# %% [markdown]
# 4. El Pipeline
